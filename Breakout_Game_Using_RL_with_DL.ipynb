# %% [markdown]
# *Breakout Game that uses Deep learning with Reinforcement Learning*

# %% [markdown]
# Done By Aditya Narayanasetti

# %%
import pygame
import math
import random

# Constant for determining the screen size.
SIZE_OF_THE_SCREEN = 424, 430
# Dimensions of the brikcs
HEIGHT_OF_BRICK  = 13
WIDTH_OF_BRICK   = 32
# Dimensions of the paddle
HEIGH_OF_PADDLE = 8
PADDLE_WIDTH  = 50
# Y coordinate for Paddle
PADDLE_Y = SIZE_OF_THE_SCREEN[1] - HEIGH_OF_PADDLE - 10
# Dimensions of the ball
BALL_DIAMETER = 12
BALL_RADIUS   = BALL_DIAMETER // 2
# X coordinate for Paddles
MAX_PADDLE_X = SIZE_OF_THE_SCREEN[0] - PADDLE_WIDTH
MAX_BALL_X   = SIZE_OF_THE_SCREEN[0] - BALL_DIAMETER
MAX_BALL_Y   = SIZE_OF_THE_SCREEN[1] - BALL_DIAMETER

# Color constants
BLACK = (0, 0, 0)
WHITE = (255, 255, 255)
BLUE  = (0, 0, 255)
COLOR_OF_BRICK = (153, 76, 0)
PADDLE_COLOR = (204,0,0)

FPS = 60
FPSCLOCK = pygame.time.Clock()

pygame.init() # Calling pygame module
screen = pygame.display.set_mode(SIZE_OF_THE_SCREEN)
pygame.display.set_caption(" BREAKOUT")
clock = pygame.time.Clock()

class Breakout:

    def __init__(self):
        self.capture = 0
        # Used 12-velocity to train
        self.ball_vel = [12,-12]
        self.paddle   = pygame.Rect(215, PADDLE_Y,PADDLE_WIDTH, HEIGH_OF_PADDLE)
        self.ball     = pygame.Rect(225,PADDLE_Y - BALL_DIAMETER,BALL_DIAMETER,BALL_DIAMETER)
        self.create_bricks()

    def create_bricks(self):
        y_ofs = 20
        self.bricks = []
        for i in range(11):
            x_ofs = 15
            for j in range(12):
                self.bricks.append(pygame.Rect(x_ofs,y_ofs,WIDTH_OF_BRICK,HEIGHT_OF_BRICK))
                x_ofs += WIDTH_OF_BRICK + 1
            y_ofs += HEIGHT_OF_BRICK + 1
    def draw_bricks(self):
        for brick in self.bricks:
            pygame.draw.rect(screen, COLOR_OF_BRICK, brick)
    def draw_paddle(self):
        pygame.draw.rect(screen, PADDLE_COLOR, self.paddle)
    def draw_ball(self):
        pygame.draw.circle(screen, WHITE, (self.ball.left + BALL_RADIUS, self.ball.top + BALL_RADIUS), BALL_RADIUS)

    def check_input(self,input_action):
        # 0-LEFT, 1-Right
        if input_action[0] == 1:
        	# Used 12-velocity to train --> self.paddle.left -= 12
            self.paddle.left -= 12
            if self.paddle.left < 0:
                self.paddle.left = 0
        if input_action[1] == 1:
        	# Likewise 12
            self.paddle.left += 12
            if self.paddle.left > MAX_PADDLE_X:
                self.paddle.left = MAX_PADDLE_X

    def move_ball(self):
        self.ball.left += self.ball_vel[0]
        self.ball.top  += self.ball_vel[1]
        if self.ball.left <= 0:
            self.ball.left = 0
            self.ball_vel[0] = -self.ball_vel[0]
        elif self.ball.left >= MAX_BALL_X:
            self.ball.left = MAX_BALL_X
            self.ball_vel[0] = -self.ball_vel[0]
        if self.ball.top < 0:
            self.ball.top = 0
            self.ball_vel[1] = -self.ball_vel[1]
        elif self.ball.top >= MAX_BALL_Y:
            self.ball.top = MAX_BALL_Y
            self.ball_vel[1] = -self.ball_vel[1]

    def take_action(self,input_action):

        pygame.event.pump()

        reward = 0.1
        terminal = False
        randNum = random.randint(0,1)

        # Get every event
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                pygame.quit()
                quit()

        screen.fill(BLACK)
        self.check_input(input_action)
        self.move_ball()

        # Handle Collisions
        for brick in self.bricks:
            if self.ball.colliderect(brick):
                reward = 2
                self.ball_vel[1] = -self.ball_vel[1]
                self.bricks.remove(brick)
                break
        if len(self.bricks) == 0:
            self.terminal = True
            self.__init__()
        if self.ball.colliderect(self.paddle):
            self.ball.top = PADDLE_Y - BALL_DIAMETER
            self.ball_vel[1] = -self.ball_vel[1]
        elif self.ball.top > self.paddle.top:
            terminal = True
            self.__init__()
            reward = -2

        self.draw_bricks()
        self.draw_ball()
        self.draw_paddle()
        # Capture screen and assign to image_data
        image_data = pygame.surfarray.array3d(pygame.display.get_surface())
        # Update the screen
        pygame.display.update()
        FPSCLOCK.tick(FPS)
        return image_data, reward, terminal

# %%
import cv2
import numpy as np
from collections import deque
import random
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as T
import torch.nn.functional as F

import os
import sys
import time


class NeuralNetwork(nn.Module):

    def __init__(self):
        super(NeuralNetwork, self).__init__()

        self.number_of_actions = 2
        self.gamma = 0.99
        self.final_epsilon = 0.05
        self.initial_epsilon = 0.1
        self.number_of_iterations = 2000
        self.replay_memory_size = 750000
        self.minibatch_size = 32
        self.explore = 3000000 # Timesteps to go from INITIAL_EPSILON to FINAL_EPSILON

        self.conv1 = nn.Conv2d(4, 32, kernel_size = 8, stride = 4)
        self.conv2 = nn.Conv2d(32, 64, 4, 2)
        self.conv3 = nn.Conv2d(64, 64, 3, 1)
        self.fc4 = nn.Linear(7 * 7 * 64, 512)
        self.fc5 = nn.Linear(512, self.number_of_actions)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        #make sure input tensor is flattened
        x = F.relu(self.fc4(x.view(x.size(0), -1)))
        return self.fc5(x)


def preprocessing(image):
	image_data = cv2.cvtColor(cv2.resize(image, (84, 84)), cv2.COLOR_BGR2GRAY)
	image_data[image_data > 0] = 255
	image_data = np.reshape(image_data,(84, 84, 1))
	image_tensor = image_data.transpose(2, 0, 1)
	image_tensor = image_tensor.astype(np.float32)
	image_tensor = torch.from_numpy(image_tensor)
	return image_tensor

def init_weights(m):
    if type(m) == nn.Conv2d or type(m) == nn.Linear:
        torch.nn.init.uniform(m.weight, -0.01, 0.01)
        m.bias.data.fill_(0.01)

def train(model, start):
    # define Adam optimizer
    optimizer = optim.Adam(model.parameters(), lr=0.0002)

    # initialize mean squared error loss
    criterion = nn.MSELoss() # crossentropy

    # instantiate game
    game_state = Breakout()

    # initialize replay memory
    D = deque()
    #replay = []

    # initial action is do nothing
    action = torch.zeros([model.number_of_actions], dtype=torch.float32)
    action[0] = 0
    image_data, reward, terminal = game_state.take_action(action)
    image_data = preprocessing(image_data)
    state = torch.cat((image_data, image_data, image_data, image_data)).unsqueeze(0) # 1-4-84-84

    # initialize epsilon value
    epsilon = model.initial_epsilon
    iteration = 0

    #epsilon = 0.0927
    #iteration = 420000
    # main infinite loop
    while iteration < model.number_of_iterations:
        # get output from the neural network
        output = model(state)[0] # Output size = torch.Size([2]) tensor([-0.0278,  1.7244]
        #output = model(state)

        # initialize action
        action = torch.zeros([model.number_of_actions], dtype=torch.float32)

        # epsilon greedy exploration
        random_action = random.random() <= epsilon
        if random_action:
            print("Random action!")

        # Pick action --> random or index of maximum q value
        action_index = [torch.randint(model.number_of_actions, torch.Size([]), dtype=torch.int)
                        if random_action
                        else torch.argmax(output)][0]

        #print("Action index shape: ", action_index.shape) # torch.Size([])

        action[action_index] = 1

        if epsilon > model.final_epsilon:
            epsilon -= (model.initial_epsilon - model.final_epsilon) / model.explore

        # get next state and reward
        image_data_1, reward, terminal = game_state.take_action(action)
        image_data_1 = preprocessing(image_data_1)

        #print("İmage data_1 shape: ", image_data_1.shape)  # 1-84-84

        state_1 = torch.cat((state.squeeze(0)[1:, :, :], image_data_1)).unsqueeze(0)   # squeeze(0).shape = 4-84-84
        #print("State_1 Shape: ", state_1.shape) # State_1 Shape = ([1, 4, 84, 84])     # squeeze(0)[1:,:,:].shape = 3-84-84
        action = action.unsqueeze(0)
        #print("Action size: ", action.shape) # 1-2
        reward = torch.from_numpy(np.array([reward], dtype=np.float32)).unsqueeze(0)
        #print("Reward size: ", reward.shape)
        # save transition to replay memory
        D.append((state, action, reward, state_1, terminal))

        # if replay memory is full, remove the oldest transition
        if len(D) > model.replay_memory_size:
            D.popleft()

        # sample random minibatch
        # it picks k unique random elements, a sample, from a sequence: random.sample(population, k)
        minibatch = random.sample(D, min(len(D), model.minibatch_size))
        # unpack minibatch

        state_batch   = torch.cat(tuple(d[0] for d in minibatch))
        #print("state_batch size: ", state_batch.shape)
        action_batch  = torch.cat(tuple(d[1] for d in minibatch))
        #print("action_batch size: ", action_batch.shape)
        reward_batch  = torch.cat(tuple(d[2] for d in minibatch))
        #print("reward_batch size: ", reward_batch.shape)
        state_1_batch = torch.cat(tuple(d[3] for d in minibatch))
        #print("state_1_batch size: ", state_1_batch.shape)

        # get output for the next state
        output_1_batch = model(state_1_batch)
        #print("output_1_batch: " , output_1_batch.shape)

        # set y_j to r_j for terminal state, otherwise to r_j + gamma*max(Q) Target Q value Bellman equation.
        y_batch = torch.cat(tuple(reward_batch[i] if minibatch[i][4]
                                  else reward_batch[i] + model.gamma * torch.max(output_1_batch[i])
                                  for i in range(len(minibatch))))


        # extract Q-value -----> column1 * column1 + column2 * column2
        # The main idea behind Q-learning is that if we had a function Q∗ :State × Action → ℝ
        #that could tell us what our return would be, if we were to take an action in a given state,
        #then we could easily construct a policy that maximizes our rewards
        q_value = torch.sum(model(state_batch) * action_batch, dim=1)
        #print("q_value: ", q_value.shape)

        # PyTorch accumulates gradients by default, so they need to be reset in each pass
        optimizer.zero_grad()

        # returns a new Tensor, detached from the current graph, the result will never require gradient
        y_batch = y_batch.detach()

        # calculate loss
        loss = criterion(q_value, y_batch)

        # do backward pass
        loss.backward()
        optimizer.step()

        # set state to be state_1
        state = state_1
        iteration += 1

        if iteration % 10000 == 0:
            torch.save(model, "trained_model/current_model_" + str(iteration) + ".pth")

        print("total iteration: {} Elapsed time: {:.2f} epsilon: {:.5f}"
               " action: {} Reward: {:.1f}".format(iteration,((time.time() - start)/60),epsilon,action_index.cpu().detach().numpy(),reward.numpy()[0][0]))

def test(model):
    game_state = Breakout()

    # initial action is do nothing
    action = torch.zeros([model.number_of_actions], dtype=torch.float32)
    action[0] = 1
    image_data, reward, terminal = game_state.take_action(action)
    image_data = preprocessing(image_data)
    state = torch.cat((image_data, image_data, image_data, image_data)).unsqueeze(0)

    while True:
        # get output from the neural network
        output = model(state)[0]

        action = torch.zeros([model.number_of_actions], dtype=torch.float32)

        # get action
        action_index = torch.argmax(output)
        action[action_index] = 1

        # get next state
        image_data_1, reward, terminal = game_state.take_action(action)
        image_data_1 = preprocessing(image_data_1)
        state_1 = torch.cat((state.squeeze(0)[1:, :, :], image_data_1)).unsqueeze(0)

        # set state to be state_1
        state = state_1

def main(mode):
    if mode == 'test':
        model = torch.load('trained_model/current_model_420000.pth', map_location='cpu').eval()
        test(model)
    elif mode == 'train':
        if not os.path.exists('trained_model/'):
            os.mkdir('trained_model/')
        model = NeuralNetwork()
        model.apply(init_weights)
        start = time.time()
        train(model, start)
    elif mode == 'continue': # You can change trained model id and keep training.
        model = torch.load('trained_model/current_model_420000.pth', map_location='cpu').eval()
        start = time.time()
        train(model, start)

if __name__ == "__main__":
    main('train')
# Out:
# <ipython-input-5-87795efda0cd>:56: UserWarning: nn.init.uniform is now deprecated in favor of nn.init.uniform_.
#   torch.nn.init.uniform(m.weight, -0.01, 0.01)
# total iteration: 1 Elapsed time: 0.00 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 2 Elapsed time: 0.00 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 3 Elapsed time: 0.00 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 4 Elapsed time: 0.00 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 5 Elapsed time: 0.00 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 6 Elapsed time: 0.00 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 7 Elapsed time: 0.00 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 8 Elapsed time: 0.01 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 9 Elapsed time: 0.01 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 10 Elapsed time: 0.01 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 11 Elapsed time: 0.01 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 12 Elapsed time: 0.01 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 13 Elapsed time: 0.01 epsilon: 0.10000 action: 0 Reward: 0.1
# Random action!
# total iteration: 14 Elapsed time: 0.01 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 15 Elapsed time: 0.01 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 16 Elapsed time: 0.01 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 17 Elapsed time: 0.01 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 18 Elapsed time: 0.01 epsilon: 0.10000 action: 0 Reward: 2.0
# total iteration: 19 Elapsed time: 0.02 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 20 Elapsed time: 0.02 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 21 Elapsed time: 0.02 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 22 Elapsed time: 0.02 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 23 Elapsed time: 0.02 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 24 Elapsed time: 0.02 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 25 Elapsed time: 0.02 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 26 Elapsed time: 0.02 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 27 Elapsed time: 0.03 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 28 Elapsed time: 0.03 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 29 Elapsed time: 0.03 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 30 Elapsed time: 0.03 epsilon: 0.10000 action: 0 Reward: 0.1
# Random action!
# total iteration: 31 Elapsed time: 0.03 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 32 Elapsed time: 0.03 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 33 Elapsed time: 0.03 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 34 Elapsed time: 0.04 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 35 Elapsed time: 0.04 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 36 Elapsed time: 0.04 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 37 Elapsed time: 0.04 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 38 Elapsed time: 0.04 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 39 Elapsed time: 0.04 epsilon: 0.10000 action: 0 Reward: -2.0
# total iteration: 40 Elapsed time: 0.04 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 41 Elapsed time: 0.05 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 42 Elapsed time: 0.05 epsilon: 0.10000 action: 0 Reward: 0.1
# Random action!
# total iteration: 43 Elapsed time: 0.05 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 44 Elapsed time: 0.05 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 45 Elapsed time: 0.05 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 46 Elapsed time: 0.05 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 47 Elapsed time: 0.05 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 48 Elapsed time: 0.06 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 49 Elapsed time: 0.06 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 50 Elapsed time: 0.06 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 51 Elapsed time: 0.06 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 52 Elapsed time: 0.06 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 53 Elapsed time: 0.06 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 54 Elapsed time: 0.06 epsilon: 0.10000 action: 0 Reward: 0.1
# Random action!
# total iteration: 55 Elapsed time: 0.07 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 56 Elapsed time: 0.07 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 57 Elapsed time: 0.07 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 58 Elapsed time: 0.07 epsilon: 0.10000 action: 0 Reward: 2.0
# total iteration: 59 Elapsed time: 0.07 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 60 Elapsed time: 0.07 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 61 Elapsed time: 0.07 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 62 Elapsed time: 0.08 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 63 Elapsed time: 0.08 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 64 Elapsed time: 0.08 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 65 Elapsed time: 0.08 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 66 Elapsed time: 0.08 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 67 Elapsed time: 0.08 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 68 Elapsed time: 0.08 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 69 Elapsed time: 0.09 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 70 Elapsed time: 0.09 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 71 Elapsed time: 0.09 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 72 Elapsed time: 0.09 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 73 Elapsed time: 0.09 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 74 Elapsed time: 0.09 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 75 Elapsed time: 0.09 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 76 Elapsed time: 0.10 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 77 Elapsed time: 0.10 epsilon: 0.10000 action: 1 Reward: 0.1
# Random action!
# total iteration: 78 Elapsed time: 0.10 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 79 Elapsed time: 0.10 epsilon: 0.10000 action: 1 Reward: -2.0
# total iteration: 80 Elapsed time: 0.10 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 81 Elapsed time: 0.10 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 82 Elapsed time: 0.10 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 83 Elapsed time: 0.11 epsilon: 0.10000 action: 0 Reward: 0.1
# Random action!
# total iteration: 84 Elapsed time: 0.11 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 85 Elapsed time: 0.11 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 86 Elapsed time: 0.11 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 87 Elapsed time: 0.11 epsilon: 0.10000 action: 0 Reward: 0.1
# Random action!
# total iteration: 88 Elapsed time: 0.11 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 89 Elapsed time: 0.11 epsilon: 0.10000 action: 0 Reward: 0.1
# Random action!
# total iteration: 90 Elapsed time: 0.12 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 91 Elapsed time: 0.12 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 92 Elapsed time: 0.12 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 93 Elapsed time: 0.12 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 94 Elapsed time: 0.12 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 95 Elapsed time: 0.12 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 96 Elapsed time: 0.12 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 97 Elapsed time: 0.13 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 98 Elapsed time: 0.13 epsilon: 0.10000 action: 0 Reward: 2.0
# total iteration: 99 Elapsed time: 0.13 epsilon: 0.10000 action: 0 Reward: 0.1
# Random action!
# total iteration: 100 Elapsed time: 0.13 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 101 Elapsed time: 0.13 epsilon: 0.10000 action: 0 Reward: 0.1
# Random action!
# total iteration: 102 Elapsed time: 0.13 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 103 Elapsed time: 0.13 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 104 Elapsed time: 0.14 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 105 Elapsed time: 0.14 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 106 Elapsed time: 0.14 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 107 Elapsed time: 0.14 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 108 Elapsed time: 0.14 epsilon: 0.10000 action: 0 Reward: 0.1
# Random action!
# total iteration: 109 Elapsed time: 0.14 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 110 Elapsed time: 0.14 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 111 Elapsed time: 0.15 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 112 Elapsed time: 0.15 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 113 Elapsed time: 0.15 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 114 Elapsed time: 0.15 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 115 Elapsed time: 0.15 epsilon: 0.10000 action: 0 Reward: 0.1
# Random action!
# total iteration: 116 Elapsed time: 0.15 epsilon: 0.10000 action: 1 Reward: 0.1
# Random action!
# total iteration: 117 Elapsed time: 0.16 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 118 Elapsed time: 0.16 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 119 Elapsed time: 0.16 epsilon: 0.10000 action: 0 Reward: -2.0
# total iteration: 120 Elapsed time: 0.16 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 121 Elapsed time: 0.17 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 122 Elapsed time: 0.17 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 123 Elapsed time: 0.17 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 124 Elapsed time: 0.17 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 125 Elapsed time: 0.17 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 126 Elapsed time: 0.18 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 127 Elapsed time: 0.18 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 128 Elapsed time: 0.18 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 129 Elapsed time: 0.18 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 130 Elapsed time: 0.18 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 131 Elapsed time: 0.19 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 132 Elapsed time: 0.19 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 133 Elapsed time: 0.19 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 134 Elapsed time: 0.19 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 135 Elapsed time: 0.19 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 136 Elapsed time: 0.20 epsilon: 0.10000 action: 1 Reward: 0.1
# Random action!
# total iteration: 137 Elapsed time: 0.20 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 138 Elapsed time: 0.20 epsilon: 0.10000 action: 1 Reward: 2.0
# total iteration: 139 Elapsed time: 0.20 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 140 Elapsed time: 0.20 epsilon: 0.10000 action: 0 Reward: 0.1
# Random action!
# total iteration: 141 Elapsed time: 0.20 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 142 Elapsed time: 0.20 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 143 Elapsed time: 0.21 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 144 Elapsed time: 0.21 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 145 Elapsed time: 0.21 epsilon: 0.10000 action: 0 Reward: 0.1
# Random action!
# total iteration: 146 Elapsed time: 0.21 epsilon: 0.10000 action: 1 Reward: 0.1
# Random action!
# total iteration: 147 Elapsed time: 0.21 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 148 Elapsed time: 0.21 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 149 Elapsed time: 0.21 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 150 Elapsed time: 0.22 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 151 Elapsed time: 0.22 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 152 Elapsed time: 0.22 epsilon: 0.10000 action: 1 Reward: 0.1
# Random action!
# total iteration: 153 Elapsed time: 0.22 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 154 Elapsed time: 0.22 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 155 Elapsed time: 0.22 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 156 Elapsed time: 0.22 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 157 Elapsed time: 0.23 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 158 Elapsed time: 0.23 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 159 Elapsed time: 0.23 epsilon: 0.10000 action: 1 Reward: -2.0
# total iteration: 160 Elapsed time: 0.23 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 161 Elapsed time: 0.23 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 162 Elapsed time: 0.23 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 163 Elapsed time: 0.23 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 164 Elapsed time: 0.24 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 165 Elapsed time: 0.24 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 166 Elapsed time: 0.24 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 167 Elapsed time: 0.24 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 168 Elapsed time: 0.24 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 169 Elapsed time: 0.24 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 170 Elapsed time: 0.24 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 171 Elapsed time: 0.25 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 172 Elapsed time: 0.25 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 173 Elapsed time: 0.25 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 174 Elapsed time: 0.25 epsilon: 0.10000 action: 0 Reward: 0.1
# Random action!
# total iteration: 175 Elapsed time: 0.25 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 176 Elapsed time: 0.25 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 177 Elapsed time: 0.25 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 178 Elapsed time: 0.26 epsilon: 0.10000 action: 0 Reward: 2.0
# total iteration: 179 Elapsed time: 0.26 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 180 Elapsed time: 0.26 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 181 Elapsed time: 0.26 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 182 Elapsed time: 0.26 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 183 Elapsed time: 0.26 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 184 Elapsed time: 0.26 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 185 Elapsed time: 0.27 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 186 Elapsed time: 0.27 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 187 Elapsed time: 0.27 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 188 Elapsed time: 0.27 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 189 Elapsed time: 0.27 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 190 Elapsed time: 0.27 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 191 Elapsed time: 0.27 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 192 Elapsed time: 0.28 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 193 Elapsed time: 0.28 epsilon: 0.10000 action: 0 Reward: 0.1
# Random action!
# total iteration: 194 Elapsed time: 0.28 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 195 Elapsed time: 0.28 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 196 Elapsed time: 0.28 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 197 Elapsed time: 0.28 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 198 Elapsed time: 0.28 epsilon: 0.10000 action: 0 Reward: 0.1
# Random action!
# total iteration: 199 Elapsed time: 0.29 epsilon: 0.10000 action: 1 Reward: -2.0
# total iteration: 200 Elapsed time: 0.29 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 201 Elapsed time: 0.29 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 202 Elapsed time: 0.29 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 203 Elapsed time: 0.29 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 204 Elapsed time: 0.29 epsilon: 0.10000 action: 0 Reward: 0.1
# Random action!
# total iteration: 205 Elapsed time: 0.30 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 206 Elapsed time: 0.30 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 207 Elapsed time: 0.30 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 208 Elapsed time: 0.30 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 209 Elapsed time: 0.30 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 210 Elapsed time: 0.30 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 211 Elapsed time: 0.30 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 212 Elapsed time: 0.31 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 213 Elapsed time: 0.31 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 214 Elapsed time: 0.31 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 215 Elapsed time: 0.31 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 216 Elapsed time: 0.31 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 217 Elapsed time: 0.31 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 218 Elapsed time: 0.31 epsilon: 0.10000 action: 0 Reward: 2.0
# total iteration: 219 Elapsed time: 0.32 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 220 Elapsed time: 0.32 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 221 Elapsed time: 0.32 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 222 Elapsed time: 0.32 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 223 Elapsed time: 0.32 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 224 Elapsed time: 0.32 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 225 Elapsed time: 0.32 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 226 Elapsed time: 0.33 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 227 Elapsed time: 0.33 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 228 Elapsed time: 0.33 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 229 Elapsed time: 0.33 epsilon: 0.10000 action: 0 Reward: 0.1
# Random action!
# total iteration: 230 Elapsed time: 0.33 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 231 Elapsed time: 0.33 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 232 Elapsed time: 0.33 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 233 Elapsed time: 0.34 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 234 Elapsed time: 0.34 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 235 Elapsed time: 0.34 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 236 Elapsed time: 0.34 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 237 Elapsed time: 0.34 epsilon: 0.10000 action: 1 Reward: 0.1
# Random action!
# total iteration: 238 Elapsed time: 0.34 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 239 Elapsed time: 0.34 epsilon: 0.10000 action: 0 Reward: -2.0
# total iteration: 240 Elapsed time: 0.35 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 241 Elapsed time: 0.35 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 242 Elapsed time: 0.35 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 243 Elapsed time: 0.35 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 244 Elapsed time: 0.35 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 245 Elapsed time: 0.35 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 246 Elapsed time: 0.35 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 247 Elapsed time: 0.36 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 248 Elapsed time: 0.36 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 249 Elapsed time: 0.36 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 250 Elapsed time: 0.36 epsilon: 0.10000 action: 1 Reward: 0.1
# Random action!
# total iteration: 251 Elapsed time: 0.36 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 252 Elapsed time: 0.36 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 253 Elapsed time: 0.37 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 254 Elapsed time: 0.37 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 255 Elapsed time: 0.37 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 256 Elapsed time: 0.37 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 257 Elapsed time: 0.37 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 258 Elapsed time: 0.38 epsilon: 0.10000 action: 0 Reward: 2.0
# total iteration: 259 Elapsed time: 0.38 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 260 Elapsed time: 0.38 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 261 Elapsed time: 0.38 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 262 Elapsed time: 0.39 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 263 Elapsed time: 0.39 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 264 Elapsed time: 0.39 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 265 Elapsed time: 0.39 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 266 Elapsed time: 0.39 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 267 Elapsed time: 0.40 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 268 Elapsed time: 0.40 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 269 Elapsed time: 0.40 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 270 Elapsed time: 0.40 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 271 Elapsed time: 0.40 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 272 Elapsed time: 0.41 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 273 Elapsed time: 0.41 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 274 Elapsed time: 0.41 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 275 Elapsed time: 0.41 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 276 Elapsed time: 0.41 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 277 Elapsed time: 0.41 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 278 Elapsed time: 0.41 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 279 Elapsed time: 0.42 epsilon: 0.10000 action: 0 Reward: -2.0
# total iteration: 280 Elapsed time: 0.42 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 281 Elapsed time: 0.42 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 282 Elapsed time: 0.42 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 283 Elapsed time: 0.42 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 284 Elapsed time: 0.42 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 285 Elapsed time: 0.42 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 286 Elapsed time: 0.43 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 287 Elapsed time: 0.43 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 288 Elapsed time: 0.43 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 289 Elapsed time: 0.43 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 290 Elapsed time: 0.43 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 291 Elapsed time: 0.43 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 292 Elapsed time: 0.43 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 293 Elapsed time: 0.44 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 294 Elapsed time: 0.44 epsilon: 0.10000 action: 1 Reward: 0.1
# Random action!
# total iteration: 295 Elapsed time: 0.44 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 296 Elapsed time: 0.44 epsilon: 0.10000 action: 0 Reward: 0.1
# total iteration: 297 Elapsed time: 0.44 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 298 Elapsed time: 0.44 epsilon: 0.10000 action: 1 Reward: 2.0
# total iteration: 299 Elapsed time: 0.44 epsilon: 0.10000 action: 1 Reward: 0.1
# total iteration: 300 Elapsed time: 0.45 epsilon: 0.09999 action: 1 Reward: 0.1
# Random action!
# total iteration: 301 Elapsed time: 0.45 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 302 Elapsed time: 0.45 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 303 Elapsed time: 0.45 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 304 Elapsed time: 0.45 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 305 Elapsed time: 0.45 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 306 Elapsed time: 0.45 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 307 Elapsed time: 0.46 epsilon: 0.09999 action: 0 Reward: 0.1
# Random action!
# total iteration: 308 Elapsed time: 0.46 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 309 Elapsed time: 0.46 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 310 Elapsed time: 0.46 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 311 Elapsed time: 0.46 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 312 Elapsed time: 0.46 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 313 Elapsed time: 0.46 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 314 Elapsed time: 0.47 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 315 Elapsed time: 0.47 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 316 Elapsed time: 0.47 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 317 Elapsed time: 0.47 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 318 Elapsed time: 0.48 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 319 Elapsed time: 0.48 epsilon: 0.09999 action: 0 Reward: -2.0
# total iteration: 320 Elapsed time: 0.48 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 321 Elapsed time: 0.48 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 322 Elapsed time: 0.48 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 323 Elapsed time: 0.49 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 324 Elapsed time: 0.49 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 325 Elapsed time: 0.49 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 326 Elapsed time: 0.49 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 327 Elapsed time: 0.49 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 328 Elapsed time: 0.49 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 329 Elapsed time: 0.49 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 330 Elapsed time: 0.50 epsilon: 0.09999 action: 1 Reward: 0.1
# Random action!
# total iteration: 331 Elapsed time: 0.50 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 332 Elapsed time: 0.50 epsilon: 0.09999 action: 1 Reward: 0.1
# Random action!
# total iteration: 333 Elapsed time: 0.50 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 334 Elapsed time: 0.50 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 335 Elapsed time: 0.51 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 336 Elapsed time: 0.51 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 337 Elapsed time: 0.51 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 338 Elapsed time: 0.51 epsilon: 0.09999 action: 1 Reward: 2.0
# total iteration: 339 Elapsed time: 0.51 epsilon: 0.09999 action: 0 Reward: 0.1
# Random action!
# total iteration: 340 Elapsed time: 0.51 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 341 Elapsed time: 0.51 epsilon: 0.09999 action: 1 Reward: 0.1
# Random action!
# total iteration: 342 Elapsed time: 0.52 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 343 Elapsed time: 0.52 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 344 Elapsed time: 0.52 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 345 Elapsed time: 0.52 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 346 Elapsed time: 0.52 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 347 Elapsed time: 0.52 epsilon: 0.09999 action: 1 Reward: 0.1
# Random action!
# total iteration: 348 Elapsed time: 0.52 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 349 Elapsed time: 0.53 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 350 Elapsed time: 0.53 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 351 Elapsed time: 0.53 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 352 Elapsed time: 0.53 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 353 Elapsed time: 0.53 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 354 Elapsed time: 0.53 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 355 Elapsed time: 0.53 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 356 Elapsed time: 0.54 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 357 Elapsed time: 0.54 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 358 Elapsed time: 0.54 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 359 Elapsed time: 0.54 epsilon: 0.09999 action: 0 Reward: -2.0
# total iteration: 360 Elapsed time: 0.54 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 361 Elapsed time: 0.54 epsilon: 0.09999 action: 0 Reward: 0.1
# Random action!
# total iteration: 362 Elapsed time: 0.54 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 363 Elapsed time: 0.55 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 364 Elapsed time: 0.55 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 365 Elapsed time: 0.55 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 366 Elapsed time: 0.55 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 367 Elapsed time: 0.55 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 368 Elapsed time: 0.55 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 369 Elapsed time: 0.55 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 370 Elapsed time: 0.56 epsilon: 0.09999 action: 1 Reward: 0.1
# Random action!
# total iteration: 371 Elapsed time: 0.56 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 372 Elapsed time: 0.56 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 373 Elapsed time: 0.56 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 374 Elapsed time: 0.56 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 375 Elapsed time: 0.56 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 376 Elapsed time: 0.56 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 377 Elapsed time: 0.57 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 378 Elapsed time: 0.57 epsilon: 0.09999 action: 0 Reward: 2.0
# Random action!
# total iteration: 379 Elapsed time: 0.57 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 380 Elapsed time: 0.57 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 381 Elapsed time: 0.57 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 382 Elapsed time: 0.57 epsilon: 0.09999 action: 0 Reward: 0.1
# Random action!
# total iteration: 383 Elapsed time: 0.58 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 384 Elapsed time: 0.58 epsilon: 0.09999 action: 1 Reward: 0.1
# Random action!
# total iteration: 385 Elapsed time: 0.58 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 386 Elapsed time: 0.58 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 387 Elapsed time: 0.58 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 388 Elapsed time: 0.59 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 389 Elapsed time: 0.59 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 390 Elapsed time: 0.59 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 391 Elapsed time: 0.59 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 392 Elapsed time: 0.60 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 393 Elapsed time: 0.60 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 394 Elapsed time: 0.60 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 395 Elapsed time: 0.60 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 396 Elapsed time: 0.60 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 397 Elapsed time: 0.61 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 398 Elapsed time: 0.61 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 399 Elapsed time: 0.61 epsilon: 0.09999 action: 0 Reward: -2.0
# total iteration: 400 Elapsed time: 0.61 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 401 Elapsed time: 0.61 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 402 Elapsed time: 0.62 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 403 Elapsed time: 0.62 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 404 Elapsed time: 0.62 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 405 Elapsed time: 0.62 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 406 Elapsed time: 0.62 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 407 Elapsed time: 0.62 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 408 Elapsed time: 0.62 epsilon: 0.09999 action: 1 Reward: 0.1
# Random action!
# total iteration: 409 Elapsed time: 0.63 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 410 Elapsed time: 0.63 epsilon: 0.09999 action: 1 Reward: 0.1
# Random action!
# total iteration: 411 Elapsed time: 0.63 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 412 Elapsed time: 0.63 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 413 Elapsed time: 0.63 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 414 Elapsed time: 0.63 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 415 Elapsed time: 0.63 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 416 Elapsed time: 0.64 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 417 Elapsed time: 0.64 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 418 Elapsed time: 0.64 epsilon: 0.09999 action: 0 Reward: 2.0
# total iteration: 419 Elapsed time: 0.64 epsilon: 0.09999 action: 1 Reward: 0.1
# Random action!
# total iteration: 420 Elapsed time: 0.64 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 421 Elapsed time: 0.64 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 422 Elapsed time: 0.64 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 423 Elapsed time: 0.65 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 424 Elapsed time: 0.65 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 425 Elapsed time: 0.65 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 426 Elapsed time: 0.65 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 427 Elapsed time: 0.65 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 428 Elapsed time: 0.65 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 429 Elapsed time: 0.65 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 430 Elapsed time: 0.66 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 431 Elapsed time: 0.66 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 432 Elapsed time: 0.66 epsilon: 0.09999 action: 0 Reward: 0.1
# Random action!
# total iteration: 433 Elapsed time: 0.66 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 434 Elapsed time: 0.66 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 435 Elapsed time: 0.66 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 436 Elapsed time: 0.66 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 437 Elapsed time: 0.67 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 438 Elapsed time: 0.67 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 439 Elapsed time: 0.67 epsilon: 0.09999 action: 0 Reward: -2.0
# total iteration: 440 Elapsed time: 0.67 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 441 Elapsed time: 0.67 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 442 Elapsed time: 0.67 epsilon: 0.09999 action: 0 Reward: 0.1
# Random action!
# total iteration: 443 Elapsed time: 0.68 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 444 Elapsed time: 0.68 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 445 Elapsed time: 0.68 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 446 Elapsed time: 0.68 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 447 Elapsed time: 0.68 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 448 Elapsed time: 0.68 epsilon: 0.09999 action: 1 Reward: 0.1
# Random action!
# total iteration: 449 Elapsed time: 0.68 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 450 Elapsed time: 0.69 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 451 Elapsed time: 0.69 epsilon: 0.09999 action: 1 Reward: 0.1
# Random action!
# total iteration: 452 Elapsed time: 0.69 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 453 Elapsed time: 0.69 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 454 Elapsed time: 0.69 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 455 Elapsed time: 0.69 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 456 Elapsed time: 0.69 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 457 Elapsed time: 0.70 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 458 Elapsed time: 0.70 epsilon: 0.09999 action: 0 Reward: 2.0
# total iteration: 459 Elapsed time: 0.70 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 460 Elapsed time: 0.70 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 461 Elapsed time: 0.70 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 462 Elapsed time: 0.70 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 463 Elapsed time: 0.70 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 464 Elapsed time: 0.71 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 465 Elapsed time: 0.71 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 466 Elapsed time: 0.71 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 467 Elapsed time: 0.71 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 468 Elapsed time: 0.71 epsilon: 0.09999 action: 0 Reward: 0.1
# Random action!
# total iteration: 469 Elapsed time: 0.71 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 470 Elapsed time: 0.71 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 471 Elapsed time: 0.72 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 472 Elapsed time: 0.72 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 473 Elapsed time: 0.72 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 474 Elapsed time: 0.72 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 475 Elapsed time: 0.72 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 476 Elapsed time: 0.72 epsilon: 0.09999 action: 1 Reward: 0.1
# Random action!
# total iteration: 477 Elapsed time: 0.72 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 478 Elapsed time: 0.73 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 479 Elapsed time: 0.73 epsilon: 0.09999 action: 0 Reward: -2.0
# total iteration: 480 Elapsed time: 0.73 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 481 Elapsed time: 0.73 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 482 Elapsed time: 0.73 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 483 Elapsed time: 0.73 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 484 Elapsed time: 0.73 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 485 Elapsed time: 0.74 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 486 Elapsed time: 0.74 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 487 Elapsed time: 0.74 epsilon: 0.09999 action: 0 Reward: 0.1
# Random action!
# total iteration: 488 Elapsed time: 0.74 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 489 Elapsed time: 0.74 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 490 Elapsed time: 0.74 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 491 Elapsed time: 0.74 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 492 Elapsed time: 0.75 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 493 Elapsed time: 0.75 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 494 Elapsed time: 0.75 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 495 Elapsed time: 0.75 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 496 Elapsed time: 0.75 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 497 Elapsed time: 0.75 epsilon: 0.09999 action: 0 Reward: 0.1
# Random action!
# total iteration: 498 Elapsed time: 0.75 epsilon: 0.09999 action: 0 Reward: 2.0
# total iteration: 499 Elapsed time: 0.76 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 500 Elapsed time: 0.76 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 501 Elapsed time: 0.76 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 502 Elapsed time: 0.76 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 503 Elapsed time: 0.76 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 504 Elapsed time: 0.76 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 505 Elapsed time: 0.76 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 506 Elapsed time: 0.77 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 507 Elapsed time: 0.77 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 508 Elapsed time: 0.77 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 509 Elapsed time: 0.77 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 510 Elapsed time: 0.77 epsilon: 0.09999 action: 0 Reward: 0.1
# Random action!
# total iteration: 511 Elapsed time: 0.77 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 512 Elapsed time: 0.77 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 513 Elapsed time: 0.78 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 514 Elapsed time: 0.78 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 515 Elapsed time: 0.78 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 516 Elapsed time: 0.78 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 517 Elapsed time: 0.78 epsilon: 0.09999 action: 0 Reward: 0.1
# Random action!
# total iteration: 518 Elapsed time: 0.78 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 519 Elapsed time: 0.79 epsilon: 0.09999 action: 1 Reward: -2.0
# total iteration: 520 Elapsed time: 0.80 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 521 Elapsed time: 0.80 epsilon: 0.09999 action: 1 Reward: 0.1
# Random action!
# total iteration: 522 Elapsed time: 0.80 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 523 Elapsed time: 0.80 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 524 Elapsed time: 0.81 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 525 Elapsed time: 0.81 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 526 Elapsed time: 0.82 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 527 Elapsed time: 0.82 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 528 Elapsed time: 0.82 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 529 Elapsed time: 0.82 epsilon: 0.09999 action: 0 Reward: 0.1
# Random action!
# total iteration: 530 Elapsed time: 0.83 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 531 Elapsed time: 0.83 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 532 Elapsed time: 0.83 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 533 Elapsed time: 0.83 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 534 Elapsed time: 0.83 epsilon: 0.09999 action: 1 Reward: 0.1
# Random action!
# total iteration: 535 Elapsed time: 0.83 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 536 Elapsed time: 0.83 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 537 Elapsed time: 0.83 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 538 Elapsed time: 0.84 epsilon: 0.09999 action: 1 Reward: 2.0
# total iteration: 539 Elapsed time: 0.84 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 540 Elapsed time: 0.84 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 541 Elapsed time: 0.84 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 542 Elapsed time: 0.84 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 543 Elapsed time: 0.84 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 544 Elapsed time: 0.85 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 545 Elapsed time: 0.85 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 546 Elapsed time: 0.85 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 547 Elapsed time: 0.85 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 548 Elapsed time: 0.85 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 549 Elapsed time: 0.85 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 550 Elapsed time: 0.85 epsilon: 0.09999 action: 0 Reward: 0.1
# Random action!
# total iteration: 551 Elapsed time: 0.86 epsilon: 0.09999 action: 1 Reward: 0.1
# Random action!
# total iteration: 552 Elapsed time: 0.86 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 553 Elapsed time: 0.86 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 554 Elapsed time: 0.86 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 555 Elapsed time: 0.86 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 556 Elapsed time: 0.86 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 557 Elapsed time: 0.86 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 558 Elapsed time: 0.87 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 559 Elapsed time: 0.87 epsilon: 0.09999 action: 1 Reward: -2.0
# total iteration: 560 Elapsed time: 0.87 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 561 Elapsed time: 0.87 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 562 Elapsed time: 0.87 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 563 Elapsed time: 0.87 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 564 Elapsed time: 0.87 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 565 Elapsed time: 0.88 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 566 Elapsed time: 0.88 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 567 Elapsed time: 0.88 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 568 Elapsed time: 0.88 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 569 Elapsed time: 0.88 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 570 Elapsed time: 0.88 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 571 Elapsed time: 0.88 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 572 Elapsed time: 0.89 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 573 Elapsed time: 0.89 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 574 Elapsed time: 0.89 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 575 Elapsed time: 0.89 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 576 Elapsed time: 0.89 epsilon: 0.09999 action: 0 Reward: 0.1
# Random action!
# total iteration: 577 Elapsed time: 0.89 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 578 Elapsed time: 0.89 epsilon: 0.09999 action: 0 Reward: 2.0
# total iteration: 579 Elapsed time: 0.90 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 580 Elapsed time: 0.90 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 581 Elapsed time: 0.90 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 582 Elapsed time: 0.90 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 583 Elapsed time: 0.90 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 584 Elapsed time: 0.90 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 585 Elapsed time: 0.90 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 586 Elapsed time: 0.91 epsilon: 0.09999 action: 1 Reward: 0.1
# total iteration: 587 Elapsed time: 0.91 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 588 Elapsed time: 0.91 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 589 Elapsed time: 0.91 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 590 Elapsed time: 0.91 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 591 Elapsed time: 0.91 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 592 Elapsed time: 0.91 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 593 Elapsed time: 0.92 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 594 Elapsed time: 0.92 epsilon: 0.09999 action: 0 Reward: 0.1
# total iteration: 595 Elapsed time: 0.92 epsilon: 0.09999 action: 1 Reward: 0.1
# ...
# total iteration: 1804 Elapsed time: 3.26 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1805 Elapsed time: 3.26 epsilon: 0.09997 action: 0 Reward: 0.1
# Random action!
# total iteration: 1806 Elapsed time: 3.26 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1807 Elapsed time: 3.26 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1808 Elapsed time: 3.26 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1809 Elapsed time: 3.27 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1810 Elapsed time: 3.27 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1811 Elapsed time: 3.27 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1812 Elapsed time: 3.27 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1813 Elapsed time: 3.27 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1814 Elapsed time: 3.27 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1815 Elapsed time: 3.28 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1816 Elapsed time: 3.28 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1817 Elapsed time: 3.28 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1818 Elapsed time: 3.28 epsilon: 0.09997 action: 1 Reward: 0.1
# Random action!
# total iteration: 1819 Elapsed time: 3.29 epsilon: 0.09997 action: 1 Reward: 0.1
# Random action!
# total iteration: 1820 Elapsed time: 3.29 epsilon: 0.09997 action: 1 Reward: 2.0
# total iteration: 1821 Elapsed time: 3.29 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1822 Elapsed time: 3.29 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1823 Elapsed time: 3.30 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1824 Elapsed time: 3.30 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1825 Elapsed time: 3.30 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1826 Elapsed time: 3.30 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1827 Elapsed time: 3.31 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1828 Elapsed time: 3.31 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1829 Elapsed time: 3.31 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1830 Elapsed time: 3.32 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1831 Elapsed time: 3.32 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1832 Elapsed time: 3.32 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1833 Elapsed time: 3.32 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1834 Elapsed time: 3.32 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1835 Elapsed time: 3.33 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1836 Elapsed time: 3.33 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1837 Elapsed time: 3.33 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1838 Elapsed time: 3.33 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1839 Elapsed time: 3.33 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1840 Elapsed time: 3.33 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1841 Elapsed time: 3.34 epsilon: 0.09997 action: 1 Reward: 0.1
# Random action!
# total iteration: 1842 Elapsed time: 3.34 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1843 Elapsed time: 3.34 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1844 Elapsed time: 3.34 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1845 Elapsed time: 3.34 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1846 Elapsed time: 3.35 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1847 Elapsed time: 3.35 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1848 Elapsed time: 3.35 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1849 Elapsed time: 3.35 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1850 Elapsed time: 3.35 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1851 Elapsed time: 3.36 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1852 Elapsed time: 3.36 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1853 Elapsed time: 3.36 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1854 Elapsed time: 3.36 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1855 Elapsed time: 3.36 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1856 Elapsed time: 3.36 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1857 Elapsed time: 3.37 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1858 Elapsed time: 3.37 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1859 Elapsed time: 3.37 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1860 Elapsed time: 3.37 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1861 Elapsed time: 3.37 epsilon: 0.09997 action: 1 Reward: 2.0
# total iteration: 1862 Elapsed time: 3.37 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1863 Elapsed time: 3.38 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1864 Elapsed time: 3.38 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1865 Elapsed time: 3.38 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1866 Elapsed time: 3.38 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1867 Elapsed time: 3.38 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1868 Elapsed time: 3.39 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1869 Elapsed time: 3.39 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1870 Elapsed time: 3.39 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1871 Elapsed time: 3.39 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1872 Elapsed time: 3.39 epsilon: 0.09997 action: 0 Reward: 0.1
# Random action!
# total iteration: 1873 Elapsed time: 3.39 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1874 Elapsed time: 3.40 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1875 Elapsed time: 3.40 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1876 Elapsed time: 3.40 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1877 Elapsed time: 3.40 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1878 Elapsed time: 3.40 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1879 Elapsed time: 3.41 epsilon: 0.09997 action: 0 Reward: 0.1
# Random action!
# total iteration: 1880 Elapsed time: 3.41 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1881 Elapsed time: 3.41 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1882 Elapsed time: 3.41 epsilon: 0.09997 action: 0 Reward: -2.0
# total iteration: 1883 Elapsed time: 3.41 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1884 Elapsed time: 3.42 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1885 Elapsed time: 3.42 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1886 Elapsed time: 3.42 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1887 Elapsed time: 3.42 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1888 Elapsed time: 3.42 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1889 Elapsed time: 3.42 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1890 Elapsed time: 3.43 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1891 Elapsed time: 3.43 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1892 Elapsed time: 3.43 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1893 Elapsed time: 3.43 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1894 Elapsed time: 3.43 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1895 Elapsed time: 3.44 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1896 Elapsed time: 3.44 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1897 Elapsed time: 3.44 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1898 Elapsed time: 3.44 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1899 Elapsed time: 3.44 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1900 Elapsed time: 3.44 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1901 Elapsed time: 3.45 epsilon: 0.09997 action: 0 Reward: 2.0
# total iteration: 1902 Elapsed time: 3.45 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1903 Elapsed time: 3.45 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1904 Elapsed time: 3.45 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1905 Elapsed time: 3.45 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1906 Elapsed time: 3.46 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1907 Elapsed time: 3.46 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1908 Elapsed time: 3.46 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1909 Elapsed time: 3.46 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1910 Elapsed time: 3.46 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1911 Elapsed time: 3.46 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1912 Elapsed time: 3.47 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1913 Elapsed time: 3.47 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1914 Elapsed time: 3.47 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1915 Elapsed time: 3.47 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1916 Elapsed time: 3.47 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1917 Elapsed time: 3.48 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1918 Elapsed time: 3.48 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1919 Elapsed time: 3.48 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1920 Elapsed time: 3.48 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1921 Elapsed time: 3.48 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1922 Elapsed time: 3.48 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1923 Elapsed time: 3.49 epsilon: 0.09997 action: 1 Reward: 0.1
# Random action!
# total iteration: 1924 Elapsed time: 3.49 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1925 Elapsed time: 3.49 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1926 Elapsed time: 3.49 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1927 Elapsed time: 3.50 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1928 Elapsed time: 3.50 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1929 Elapsed time: 3.50 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1930 Elapsed time: 3.51 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1931 Elapsed time: 3.51 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1932 Elapsed time: 3.51 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1933 Elapsed time: 3.51 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1934 Elapsed time: 3.52 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1935 Elapsed time: 3.52 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1936 Elapsed time: 3.52 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1937 Elapsed time: 3.52 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1938 Elapsed time: 3.53 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1939 Elapsed time: 3.53 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1940 Elapsed time: 3.53 epsilon: 0.09997 action: 1 Reward: 2.0
# total iteration: 1941 Elapsed time: 3.53 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1942 Elapsed time: 3.53 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1943 Elapsed time: 3.54 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1944 Elapsed time: 3.54 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1945 Elapsed time: 3.54 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1946 Elapsed time: 3.54 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1947 Elapsed time: 3.54 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1948 Elapsed time: 3.54 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1949 Elapsed time: 3.55 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1950 Elapsed time: 3.55 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1951 Elapsed time: 3.55 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1952 Elapsed time: 3.55 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1953 Elapsed time: 3.55 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1954 Elapsed time: 3.56 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1955 Elapsed time: 3.56 epsilon: 0.09997 action: 0 Reward: 0.1
# Random action!
# total iteration: 1956 Elapsed time: 3.56 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1957 Elapsed time: 3.56 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1958 Elapsed time: 3.56 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1959 Elapsed time: 3.56 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1960 Elapsed time: 3.57 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1961 Elapsed time: 3.57 epsilon: 0.09997 action: 1 Reward: -2.0
# total iteration: 1962 Elapsed time: 3.57 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1963 Elapsed time: 3.57 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1964 Elapsed time: 3.57 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1965 Elapsed time: 3.58 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1966 Elapsed time: 3.58 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1967 Elapsed time: 3.58 epsilon: 0.09997 action: 0 Reward: 0.1
# Random action!
# total iteration: 1968 Elapsed time: 3.58 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1969 Elapsed time: 3.58 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1970 Elapsed time: 3.58 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1971 Elapsed time: 3.59 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1972 Elapsed time: 3.59 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1973 Elapsed time: 3.59 epsilon: 0.09997 action: 1 Reward: 0.1
# Random action!
# total iteration: 1974 Elapsed time: 3.59 epsilon: 0.09997 action: 1 Reward: 0.1
# Random action!
# total iteration: 1975 Elapsed time: 3.59 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1976 Elapsed time: 3.60 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1977 Elapsed time: 3.60 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1978 Elapsed time: 3.60 epsilon: 0.09997 action: 1 Reward: 0.1
# Random action!
# total iteration: 1979 Elapsed time: 3.60 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1980 Elapsed time: 3.60 epsilon: 0.09997 action: 1 Reward: 2.0
# total iteration: 1981 Elapsed time: 3.61 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1982 Elapsed time: 3.61 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1983 Elapsed time: 3.61 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1984 Elapsed time: 3.61 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1985 Elapsed time: 3.61 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1986 Elapsed time: 3.61 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1987 Elapsed time: 3.62 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1988 Elapsed time: 3.62 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1989 Elapsed time: 3.62 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1990 Elapsed time: 3.62 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1991 Elapsed time: 3.62 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1992 Elapsed time: 3.63 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1993 Elapsed time: 3.63 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1994 Elapsed time: 3.63 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1995 Elapsed time: 3.63 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1996 Elapsed time: 3.63 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1997 Elapsed time: 3.63 epsilon: 0.09997 action: 0 Reward: 0.1
# total iteration: 1998 Elapsed time: 3.64 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 1999 Elapsed time: 3.64 epsilon: 0.09997 action: 1 Reward: 0.1
# total iteration: 2000 Elapsed time: 3.64 epsilon: 0.09997 action: 1 Reward: 0.1

# %% [markdown]
# 1. **Imported Libraries**: The code imports several libraries including `pygame`, `math`, `random`, `cv2`, `numpy`, `torch`, and related modules for neural network training.
#
# 2. **Constants and Parameters**: Constants such as screen size, dimensions of bricks, paddle, and ball, colors, and game parameters like FPS are defined at the beginning of the script. This makes it easy to adjust these values if needed.
#
# 3. **Breakout Class**: This class defines the Breakout game environment and its functionalities. It includes methods for initializing the game, creating bricks, drawing elements (bricks, paddle, ball), handling user input, moving the ball, and taking actions in the game.
#
# 4. **Neural Network Class**: This class defines the neural network architecture for the Q-learning algorithm. It includes convolutional layers (`Conv2d`), fully connected layers (`Linear`), and the forward method for processing input images.
#
# 5. **Preprocessing Function**: This function preprocesses images by resizing them to 84x84 pixels, converting to grayscale, and reshaping to the required format for input to the neural network.
#
# 6. **Training Function**: The `train` function implements the Q-learning algorithm. It initializes the game environment, neural network, optimizer, and replay memory. It iterates through episodes, selecting actions based on an epsilon-greedy policy, updating the Q-values, and sampling minibatches from the replay memory for training.
#
# 7. **Main Function**: The `main` function determines the mode of operation (`train`, `test`, or `continue`) and executes the corresponding logic. In training mode, it initializes a neural network, starts training, and saves the trained model. In test mode, it loads a pre-trained model and evaluates its performance in the game environment. In continue mode, it resumes training from a pre-trained model.
#
# 8. **Overall Structure**: The code follows a structured approach with clear separation of concerns. The game logic is encapsulated within the `Breakout` class, while the neural network training logic is encapsulated within the `NeuralNetwork` class and related functions. The main function orchestrates the training or testing process based on the chosen mode.
#
# 9. **Comments and Documentation**: The code includes comments explaining the purpose of each function, method, and significant code block. This helps in understanding the code and its functionalities.
#
# 10. **Potential Improvements**:
#     - The code could benefit from additional documentation, especially for complex functions and methods.
#     - Error handling mechanisms could be added to handle exceptions and edge cases gracefully.
#     - Performance optimizations such as parallelization could be explored to improve training efficiency.
#     - Hyperparameters tuning and experimentation with different network architectures could be conducted to enhance learning performance.
#     - Visualization tools could be incorporated to monitor training progress and analyze agent behavior.
#     - Unit tests could be implemented to ensure the correctness of individual components.
